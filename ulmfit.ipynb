# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 1. 病种高套（BZGY）基本建模思路
#
# * 病种高套指在DRGs或者单病种付费支付制度下，医院高编病组,套取超额报销的违规行为。
#
# <p>住院结束后医院需要把入院诊断，出院诊断和每日使用明细和花费上传给医保局. 医院可以轻易修改出院诊断，但每日明细耗材涉及到药品进销存等，不易篡改。因为我们可以使用大量住院单据，训练从明细->出院诊断的分类模型。对于每个住院单据，我们使用分类模型判断其出院诊断，如果模型输出和实际商保诊断不符，且模型推断的诊断对应报销金额大于医院实际上报诊断时，则该单据有较大的病种高套嫌疑</p>

# %% [markdown]
# # 2. ULMFIT 迁移学习模型

# %% [markdown]
# #### Universal Language Model Fine-tuning for Text Classification
# https://arxiv.org/abs/1801.06146

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# pick ICDs with enough sample
import pyspark.sql.functions as pyspark_F


from fastai import *
from fastai.text import *
from pyspark import SparkConf
from pyspark.sql import SparkSession

from pyspark.sql.functions import pandas_udf,PandasUDFType,concat_ws,collect_list
from pyspark.sql.types import *

# spark.stop()
conf = SparkConf().setAppName('BZGT').setMaster('local[*]')
spark = SparkSession.builder.config(conf=conf).config("spark.driver.memory", "35g").config("spark.local.dir", "/media/data1/data/tmp").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.0.102.8:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>BZGT</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## 4.1 在全量单据上训练语言模型

# %%
# 全量数据！！！

# DETAIL_PATH_FULL = "./data/1month/detail"

# detail_full = spark.read.parquet(DETAIL_PATH_FULL).union(spark.read.parquet(DETAIL_PATH_INHOSP))

# print(detail_full.count())

# %%
DETAIL_PATH_INHOSP = "./data/inHosp/detail"

detail_full = spark.read.parquet(DETAIL_PATH_INHOSP)
data_full = detail_full.select(["REGISTER_NO","MED_PROJECT_NAME"]).groupby("REGISTER_NO").agg(concat_ws(" ", collect_list("MED_PROJECT_NAME")).alias("details"))
# 小数据
# data = data

# %%
data = data_full.toPandas()

# %% [markdown]
# 使用 Sentence Piece Encoder 来处理明细名称非标准的问题：https://github.com/google/sentencepiece

# %%
# Fastai has a bug regarding ssp:https://forums.fast.ai/t/trouble-saving-with-sentencepiece-tokenizer/42143
def get_default_size(texts, max_vocab_sz):
    "Either max_vocab_sz or one quarter of the number of unique words in `texts`"
    cnt = Counter()
    for t in texts: 
        cnt.update(t.split())
        if len(cnt)//4 > max_vocab_sz: return max_vocab_sz
    res = len(cnt)//4
    while res%8 != 0: res+=1
    return res

def train_sentencepiece_fixed(texts:Collection[str], path:PathOrStr, pre_rules: ListRules=None, post_rules:ListRules=None, 
    vocab_sz:int=None, max_vocab_sz:int=5000, model_type:str='unigram', max_sentence_len:int=20480, lang='en',
    char_coverage=None, tmp_dir='tmp', enc='utf8'):
    "Train a sentencepiece tokenizer on `texts` and save it in `path/tmp_dir`"
    from sentencepiece import SentencePieceTrainer
    cache_dir = Path(path)/tmp_dir
    os.makedirs(cache_dir, exist_ok=True)
    if vocab_sz is None: vocab_sz=get_default_size(texts, max_vocab_sz)
    raw_text_path = cache_dir / 'all_text.out'
    with open(raw_text_path, 'w', encoding=enc) as f: f.write("\n".join(texts))
    spec_tokens = ['\u2581'+s for s in defaults.text_spec_tok]
    SentencePieceTrainer.Train(" ".join([
        f"--input={raw_text_path} --max_sentence_length={max_sentence_len}",
        f"--character_coverage=0.9998",
        f"--unk_id={len(defaults.text_spec_tok)} --pad_id=-1 --bos_id=-1 --eos_id=-1",
        f"--user_defined_symbols={','.join(spec_tokens)}",
        f"--model_prefix={cache_dir/'spm'} --vocab_size={vocab_sz} --model_type={model_type}"]))
    raw_text_path.unlink()
    return cache_dir

class FixSSP(SPProcessor):
     def __init__(self,pre_rules: ListRules=None, post_rules:ListRules=None, vocab_sz:int=None,
                 max_vocab_sz:int=10000, model_type:str='unigram', max_sentence_len:int=25480, lang='cn',
                 char_coverage=None, tmp_dir='tmp', mark_fields:bool=False, include_bos:bool=True, 
                 include_eos:bool=False,  enc='utf8', **kwargs):
            super().__init__(**kwargs)
            self.train_func = partial(train_sentencepiece_fixed, pre_rules=pre_rules, post_rules=post_rules, vocab_sz=vocab_sz,
                max_vocab_sz=max_vocab_sz, model_type=model_type, max_sentence_len=max_sentence_len, lang=lang,
                char_coverage=char_coverage, tmp_dir=tmp_dir, enc=enc)

# %%
# from sentencepiece import SentencePieceProcessor
# tok = SentencePieceProcessor()
# tok.load("./tmp/spm.model")

# tok.encode_as_pieces("穿刺组织活断,尿素氮测定（急诊）,山药（配方颗粒）,静脉穿刺置管术,视黄醇结合蛋白")
# Out:
# ['▁',
#  '穿',
#  '刺',
#  '组',
#  '织',
#  '活',
#  '断',
#  ',',
#  '尿',
#  '素',
#  '氮',
#  '测定',
#  '(',
#  '急诊',
#  ')',
#  ',',
#  '山',
#  '药',
#  '(',
#  '配',
#  '方',
#  '颗粒',
#  ')',
#  ',',
#  '静',
#  '脉',
#  '穿',
#  '刺',
#  '置',
#  '管',
#  '术',
#  ',',
#  '视',
#  '黄',
#  '醇',
#  '结',
#  '合',
#  '蛋',
#  '白']

# %% [markdown]
# ## 创建语言模型

# %%
bs=128
databunch = (TextList.from_df(data,cols="details", processor=[FixSSP(max_vocab_sz=8000)])
             .split_by_rand_pct(0.1, seed=42)
             .label_for_lm()
             .databunch(bs=bs,num_workers=1))

# %%
databunch.vocab.itos
# Out:
# ['▁xxunk',
#  '▁xxpad',
#  '▁xxbos',
#  '▁xxeos',
#  '▁xxfld',
#  '▁xxmaj',
#  '▁xxup',
#  '▁xxrep',
#  '▁xxwrep',
#  '<unk>',
#  '▁',
#  '(',
#  ')',
#  '▁氯化钠',
#  '医院',
#  '住院',
#  '测定',
#  '▁鼻导管吸氧',
#  '三',
#  '、',
#  '-',
#  '▁血氧饱和度监测',
#  '级',
#  '▁等',
#  '级护理',
#  '查',
#  '诊',
#  '费',
#  '▁普通病房床位费',
#  '▁一次性真空采血器',
#  '▁心电监护',
#  '▁自费诊疗及服务项目',
#  '▁/',
#  '输液',
#  '▁静脉',
#  '含输液器',
#  '▁一次性注射器',
#  'c',
#  '二级',
#  '▁省',
#  '▁特级护理',
#  'd',
#  '▁葡萄糖测定',
#  '▁一般专项护理',
#  '▁血清',
#  '▁静脉置管冲洗',
#  '门诊',
#  '市离休',
#  '颗粒',
#  '▁葡萄糖',
#  't',
#  '▁血清载脂蛋白',
#  'b',
#  '配',
#  '方',
#  '▁静脉注射',
#  '部位',
#  '▁氯化钾',
#  'α',
#  '▁自费费用',
#  '▁计算机图文报告',
#  'o',
#  '住院可使用的诊疗项目',
#  '急诊',
#  'ca',
#  '▁贴敷疗法',
#  '抗原',
#  '▁维生素',
#  '抗体测定',
#  '▁静脉采血',
#  '▁糖类',
#  'a',
#  '▁穴位贴敷治疗',
#  'r',
#  '五',
#  '▁血浆',
#  '▁钙测定',
#  '▁血',
#  '常规',
#  '分类',
#  '▁氨溴索',
#  'e',
#  '▁抗',
#  'i',
#  '抗原测定',
#  '一个',
#  'aa',
#  '▁超',
#  '治疗',
#  '二',
#  '▁氧气雾化吸入',
#  'ct',
#  '3)',
#  '敏',
#  '时间测定',
#  '▁静脉穿刺置管术',
#  '▁一次性留置针',
#  '18',
#  's',
#  '一级',
#  '反应蛋白测定',
#  '体测定',
#  '针',
#  '▁镁测定',
#  '▁布地奈德',
#  '▁皮下注射',
#  '▁钾测定',
#  '▁钠测定',
#  '聚',
#  '▁腺苷脱氨酶测定',
#  '▁血清胆碱脂酶测定',
#  'im',
#  'er',
#  '▁氯测定',
#  'l',
#  '▁无机磷测定',
#  'igm',
#  '素',
#  'igg',
#  '▁一次性延长管',
#  'hc',
#  'γ',
#  '谷氨酰基转移酶测定',
#  'pt',
#  '市离休干部可使用的治疗性西药',
#  '免疫球蛋白',
#  '涂',
#  'ai',
#  '盐',
#  '▁中药',
#  '面积',
#  '10%',
#  '体表',
#  '擦',
#  '定量测定',
#  '血型鉴定',
#  '▁血清碱性磷酸酶测定',
#  '▁血同型半胱氨酸测定',
#  '碳酸氢',
#  '3',
#  '▁淀粉酶测定',
#  '个',
#  '▁血清天门冬氨酸氨基转移酶测定',
#  '岩藻糖苷酶测定',
#  '住院可使用的一次性材料',
#  '▁尿常规',
#  '▁肌酐测定',
#  '▁葡萄糖氯化钠',
#  '▁敷贴',
#  '常规检查',
#  '体',
#  '6',
#  '▁常规心电图检查',
#  '灸',
#  '细胞',
#  '19',
#  '▁持续血压监测',
#  '▁乳酸脱氢酶测定',
#  '多',
#  'mb',
#  '片',
#  '▁血清肌酸激酶',
#  '2',
#  '穴位',
#  '(≥3',
#  'f',
#  '▁肌肉注射',
#  '压',
#  '▁血清丙氨酸氨基转移酶测定',
#  '1',
#  '4',
#  '▁自费一次性材料',
#  'ii',
#  '葡萄糖',
#  '特异性',
#  '层',
#  '▁血清低密度脂蛋白胆固醇测定',
#  '▁血清总胆汁酸测定',
#  '▁血清总胆红素测定',
#  '▁一次性鼻导管',
#  '耳',
#  '彩超',
#  '▁粪便常规',
#  'an',
#  '双',
#  'p',
#  '同工酶活性测定',
#  '▁视黄醇结合蛋白测定',
#  '不含输液器',
#  '▁血清尿酸测定',
#  '▁特布他林',
#  '▁血清直接胆红素测定',
#  '螺旋',
#  '▁左氧氟沙星',
#  '及以上',
#  '▁超声药物透入治疗',
#  '胶囊',
#  '▁微量泵或输液泵加收',
#  '▁复方氯化钠',
#  '▁丙型肝炎抗体',
#  '豆',
#  '▁血清白蛋白测定',
#  '▁奥美拉唑',
#  '▁异丙托溴铵',
#  '平扫',
#  '▁血清总蛋白测定',
#  '癌',
#  '▁甲胎蛋白测定',
#  '▁血清前白蛋白测定',
#  '活',
#  '隐',
#  '耳穴',
#  '氨酸',
#  '▁呋塞米',
#  '血试验',
#  '胚',
#  '▁粪便',
#  '排',
#  '▁肝素帽',
#  '▁血清肌酸激酶测定',
#  '20',
#  '扫描加收',
#  '▁16',
#  '酶',
#  'ea',
#  '▁螺旋',
#  '微球蛋白测定',
#  '索',
#  '9',
#  '▁β',
#  '▁凝血功能常规检查',
#  '▁乙肝',
#  '▁血清间接胆红素测定',
#  '▁血清果糖胺测定',
#  '注射针头',
#  '▁乙肝三系检查',
#  '▁耳',
#  '▁精密输液器',
#  '▁尿素氮测定',
#  '125',
#  '术',
#  '流',
#  '血',
#  '酸',
#  '抗',
#  '原',
#  '碘',
#  '法',
#  '胞',
#  '[',
#  ']',
#  'n',
#  '坦',
#  '内',
#  'v',
#  '肽',
#  '降',
#  'm',
#  '链',
#  '单',
#  '埋',
#  '艾',
#  '状',
#  '类',
#  '生',
#  '元',
#  '率',
#  '管',
#  '川',
#  '黄',
#  '线',
#  '7',
#  '子',
#  '切',
#  '≤',
#  '腔',
#  '前',
#  '脂',
#  '洛',
#  '沉',
#  '氨',
#  '通',
#  'h',
#  '唑',
#  '条',
#  '罗',
#  '特',
#  '皮',
#  '—',
#  '器',
#  '甲',
#  '曲',
#  '量',
#  '大',
#  '胺',
#  '新',
#  '心',
#  '药',
#  '骨',
#  '5',
#  '奥',
#  '白',
#  '段',
#  '参',
#  '辛',
#  '导',
#  '罐',
#  '鳞',
#  '头',
#  '可',
#  '定',
#  'y',
#  '性',
#  '磁',
#  '比',
#  '草',
#  '丸',
#  '氯',
#  '肝',
#  '口',
#  '动',
#  '松',
#  '振',
#  '冲',
#  '物',
#  '沙',
#  '分',
#  'β',
#  '尼',
#  '感',
#  '镜',
#  '电',
#  '石',
#  '眼',
#  '酮',
#  '包',
#  '香',
#  '带',
#  '舒',
#  '乳',
#  '利',
#  '脑',
#  '一',
#  '西',
#  '化',
#  '高',
#  '碱',
#  '米',
#  '增',
#  '共',
#  '.',
#  '君',
#  '胡',
#  '试',
#  '钙',
#  '成',
#  '巴',
#  '麻',
#  '气',
#  '液',
#  '水',
#  '门',
#  '乙',
#  '洗',
#  '氧',
#  '膜',
#  '低',
#  '区',
#  '经',
#  '仁',
#  '卡',
#  '合',
#  '平',
#  '加',
#  '半',
#  '小',
#  '光',
#  '8',
#  '酰',
#  '核',
#  '替',
#  '中',
#  '如',
#  '脉',
#  '维',
#  '次',
#  '膏',
#  '速',
#  '日',
#  '肠',
#  '微',
#  '油',
#  '拉',
#  '型',
#  '宁',
#  '花',
#  '人',
#  '腹',
#  '或',
#  '母',
#  '/',
#  '芬',
#  '乌',
#  '苯',
#  '相',
#  '红',
#  '贝',
#  '磷',
#  '天',
#  '尿',
#  '醇',
#  '清',
#  '用',
#  '胃',
#  '龙',
#  '腺',
#  '干',
#  '胸',
#  '山',
#  'x',
#  '藤',
#  '丹',
#  '空',
#  '叶',
#  '容',
#  '手',
#  '宫',
#  '克',
#  '硫',
#  '隙',
#  '吸',
#  '美',
#  ',',
#  '金',
#  '马',
#  '形',
#  '灵',
#  '风',
#  '样',
#  '菌',
#  '羟',
#  '康',
#  '酚',
#  '隔',
#  '麦',
#  '尔',
#  '刺',
#  '力',
#  '肌',
#  '神',
#  'k',
#  '超',
#  '囊',
#  '林',
#  '椎',
#  'q',
#  '换',
#  '酯',
#  '透',
#  '养',
#  '穿',
#  '部',
#  '吡',
#  '解',
#  '输',
#  '延',
#  '补',
#  '司',
#  '副',
#  '精',
#  '露',
#  '质',
#  '连',
#  '火',
#  '射',
#  '侧',
#  '簇',
#  '莫',
#  '结',
#  '星',
#  '注',
#  '强',
#  '七',
#  '糖',
#  '肉',
#  '丙',
#  '颈',
#  '起',
#  '角',
#  '色',
#  '根',
#  '断',
#  '复',
#  '剖',
#  '取',
#  '固',
#  '青',
#  '异',
#  '滴',
#  '+',
#  '钠',
#  '位',
#  '百',
#  '木',
#  '图',
#  'j',
#  '亚',
#  '激',
#  '指',
#  '梗',
#  '桂',
#  '度',
#  '栓',
#  '阴',
#  '监',
#  '像',
#  '后',
#  '儿',
#  '依',
#  '支',
#  '套',
#  '牛',
#  '学',
#  '瓜',
#  '理',
#  '安',
#  '视',
#  '剂',
#  '胆',
#  '英',
#  '苏',
#  '碎',
#  '痛',
#  '无',
#  '土',
#  '病',
#  '铁',
#  '汀',
#  '塞',
#  '鼻',
#  '那',
#  '腙',
#  '床',
#  '冷',
#  '味',
#  '附',
#  '珠',
#  '韦',
#  '能',
#  '筛',
#  '长',
#  '外',
#  '及',
#  '持',
#  'u',
#  '价',
#  '孕',
#  '计',
#  '表',
#  '系',
#  '布',
#  '除',
#  '帕',
#  '伤',
#  '姜',
#  '铵',
#  '脱',
#  '溴',
#  '泻',
#  '疗',
#  '软',
#  '架',
#  '的',
#  '庚',
#  '造',
#  '朴',
#  '张',
#  '厚',
#  '总',
#  '列',
#  '炎',
#  '照',
#  '消',
#  '痔',
#  '′',
#  '蛇',
#  '髓',
#  '数',
#  '正',
#  '夹',
#  '抑',
#  '鲜',
#  '兰',
#  '右',
#  '自',
#  '种',
#  '明',
#  '颅',
#  '环',
#  '球',
#  '胰',
#  '虫',
#  '鱼',
#  '立',
#  '全',
#  '介',
#  '菊',
#  '踝',
#  '源',
#  '哌',
#  '项',
#  '疱',
#  '制',
#  '泰',
#  '巨',
#  '腕',
#  '胶',
#  '含',
#  '稳',
#  '粘',
#  '热',
#  '昔',
#  '托',
#  '袋',
#  '壳',
#  '下',
#  '肾',
#  '织',
#  '行',
#  '去',
#  '开',
#  '溶',
#  '听',
#  '远',
#  '于',
#  '实',
#  '旋',
#  '谷',
#  '修',
#  '发',
#  '银',
#  '矛',
#  '磺',
#  '倍',
#  '箱',
#  '轻',
#  '上',
#  '独',
#  '粉',
#  '组',
#  '止',
#  '令',
#  'λ',
#  '野',
#  '泵',
#  '班',
#  '柱',
#  '左',
#  '间',
#  '直',
#  '有',
#  '果',
#  '啶',
#  '疮',
#  '六',
#  '咪',
#  '脊',
#  '胎',
#  '蓝',
#  '氮',
#  '钾',
#  '重',
#  '专',
#  '晶',
#  '周',
#  '滑',
#  '凝',
#  '声',
#  '肿',
#  '德',
#  '寄',
#  '离',
#  '肺',
#  '烷',
#  '还',
#  '路',
#  '推',
#  '杞',
#  '机',
#  '其',
#  '咽',
#  '达',
#  '治',
#  '蓉',
#  '滨',
#  '纤',
#  '喉',
#  '深',
#  '密',
#  '脲',
#  '板',
#  '屈',
#  '镇',
#  '底',
#  '来',
#  '网',
#  '饼',
#  '非',
#  '乐',
#  '折',
#  '点',
#  '芷',
#  '障',
#  '散',
#  '冰',
#  '产',
#  '弓',
#  '篮',
#  '>',
#  '与',
#  '广',
#  '静',
#  '罩',
#  '伏',
#  '<',
#  '面',
#  '减',
#  '闭',
#  '功',
#  '医',
#  '冻',
#  'g',
#  '衰',
#  '知',
#  '栀',
#  '染',
#  '岛',
#  '苓',
#  '雷',
#  '式',
#  '植',
#  '觉',
#  '便',
#  '络',
#  '毒',
#  '皂',
#  '和',
#  '莲',
#  '印',
#  '砂',
#  '蝶',
#  '喘',
#  '鳖',
#  '房',
#  '尖',
#  '健',
#  '淋',
#  '螺',
#  '?',
#  '杆',
#  '筋',
#  '变',
#  '宝',
#  '咳',
#  '氏',
#  '保',
#  '蜡',
#  '赖',
#  '真',
#  '喷',
#  '打',
#  '不',
#  '残',
#  '芦',
#  '伪',
#  '奇',
#  '瘤',
#  '缝',
#  '波',
#  '柯',
#  '萨',
#  '余',
#  '厌',
#  '舌',
#  '斯',
#  '括',
#  '尾',
#  '眩',
#  '失',
#  '音',
#  '雌',
#  '腱',
#  '症',
#  '之',
#  '栗',
#  '迈',
#  '运',
#  '烧',
#  '股',
#  '瘘',
#  '危',
#  '勒',
#  '息',
#  '肢',
#  '预',
#  '交',
#  '移',
#  '\ue005',
#  '常',
#  '集',
#  '齿',
#  '祛',
#  '芙',
#  '刷',
#  '疝',
#  '痹',
#  '设',
#  '愈',
#  '采',
#  '窦',
#  '蝉',
#  '钩',
#  '灯',
#  '裂',
#  '谱',
#  '纳',
#  '丛',
#  '\ue001',
#  '本',
#  '景',
#  '巯',
#  '枯',
#  '渗',
#  '耐',
#  '苋',
#  '粗',
#  '近',
#  '击',
#  '痰',
#  '翼',
#  '整',
#  '回',
#  '封',
#  '纵',
#  '佐',
#  '释',
#  '件',
#  '极',
#  '润',
#  '夫',
#  '节',
#  '抽',
#  '宗',
#  '饮',
#  '八',
#  '初',
#  '卓',
#  '死',
#  '盆',
#  '过',
#  '跖',
#  '菜',
#  '代',
#  '脾',
#  '目',
#  '臂',
#  '智',
#  '酊',
#  '女',
#  '季',
#  '孔',
#  '阈',
#  '适',
#  '滤',
#  '免',
#  '模',
#  '尪',
#  '爱',
#  '别',
#  '疫',
#  '缩',
#  '十',
#  '桃',
#  '杉',
#  '永',
#  '损',
#  '然',
#  '记',
#  '足',
#  '衍',
#  '疡',
#  '铝',
#  'z',
#  '牙',
#  '咯',
#  '裸',
#  '颌',
#  '瘟',
#  '窄',
#  '妇',
#  '萘',
#  '象',
#  '调',
#  '滞',
#  '最',
#  '阻',
#  '积',
#  '室',
#  '粒',
#  '泡',
#  '短',
#  '院',
#  '转',
#  '镁',
#  '同',
#  '焦',
#  '着',
#  '帽',
#  '当',
#  '提',
#  '年',
#  '浆',
#  '孟',
#  '脏',
#  '毛',
#  '受',
#  '旁',
#  '柴',
#  '伸',
#  '藻',
#  '反',
#  '悬',
#  '摄',
#  '甜',
#  '规',
#  '埃',
#  '顿',
#  '浅',
#  '华',
#  '迪',
#  '字',
#  '浸',
#  '归',
#  '绒',
#  '芩',
#  '衣',
#  '云',
#  '嗜',
#  '文',
#  '即',
#  '等',
#  '紧',
#  '浮',
#  '榆',
#  '划',
#  '旱',
#  '墨',
#  '拟',
#  '糜',
#  '屏',
#  '追',
#  '月',
#  '辐',
#  '竭',
#  '围',
#  '溃',
#  '榄',
#  '霍',
#  '乱',
#  '壁',
#  '弧',
#  '何',
#  '泥',
#  '馒',
#  '餐',
#  '巩',
#  '蝎',
#  '王',
#  '硬',
#  '猪',
#  '锌',
#  '泛',
#  '碟',
#  '柳',
#  '茹',
#  '贞',
#  '棱',
#  '捏',
#  '蒡',
#  '恒',
#  '柔',
#  '灶',
#  '雪',
#  '触',
#  '朋',
#  '蓄',
#  '萹',
#  '坏',
#  '鸭',
#  '葶',
#  ...]

# %%
learn = language_model_learner(databunch, AWD_LSTM, drop_mult=0.1, wd=0.1, pretrained=False).to_fp16()
lr = 3e-3
lr *= bs/48  # Scale learning rate by batch size

# %%
import warnings
warnings.filterwarnings('ignore')

learn.unfreeze()
learn.fit_one_cycle(1, lr, moms=(0.8,0.7))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='3', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.33% [1/3 43:23<1:26:46]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.219202</td>
#       <td>1.284387</td>
#       <td>0.704334</td>
#       <td>43:22</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='747' class='' max='82188', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.91% [747/82188 00:22<41:17 1.1966]
#     </div>
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-f836dcc0f5c2> in <module>
#       3
#       4 learn.unfreeze()
# ----> 5 learn.fit_one_cycle(3, lr, moms=(0.8,0.7))
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      21     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      22                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 23     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      24
#      25 def fit_fc(learn:Learner, tot_epochs:int=1, lr:float=defaults.lr,  moms:Tuple[float,float]=(0.95,0.85), start_pct:float=0.72,
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      32     if opt is not None:
#      33         loss,skip_bwd = cb_handler.on_backward_begin(loss)
# ---> 34         if not skip_bwd:                     loss.backward()
#      35         if not cb_handler.on_backward_end(): opt.step()
#      36         if not cb_handler.on_step_end():     opt.zero_grad()
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
# --> 127         allow_unreachable=True)  # allow_unreachable flag
#     128
#     129
#
# KeyboardInterrupt:

# %%
lm_fns = ['./lm_wt', './lm_wt_vocab']
learn.to_fp32().save(lm_fns[0], with_opt=False)
learn.data.vocab.save(lm_fns[1])

# %% [markdown]
# ## 4.2 在（drgs）住院单据上精调语言模型-Domain Fine Tune

# %%
REGISTER_PATH = "./data/inHosp/register"
DETAIL_PATH = "./data/inHosp/detail"
COMBINED_PATH = "./data/inHosp/combined"

#从医保报销的单据表中抽取住院单据以及其对应明细清单
register = spark.read.parquet(REGISTER_PATH)
detail = spark.read.parquet(DETAIL_PATH)
combine = spark.read.parquet(COMBINED_PATH)
print(register.count())
print(detail.count())
print(combine.count())



### filter out diseases with few samples

min_sample = 200

icd_diagnosis = \
register.select(['out_hosp_diagnosisname','out_hosp_diagnosiscode']).dropna().\
filter(pyspark_F.length("out_hosp_diagnosiscode")>=5).\
withColumn("ICD4", register.out_hosp_diagnosiscode.substr(0,5)).\
groupby(['out_hosp_diagnosisname','ICD4']).count().\
filter(f"count >= {min_sample}").\
sort(["out_hosp_diagnosisname",]).collect()

icd_diagnosis_dict = {}
for row in icd_diagnosis:
    icd_diagnosis_dict[row.ICD4] = row.out_hosp_diagnosisname
len(icd_diagnosis_dict)

### 查看数据

data_inhosp = \
combine.filter(pyspark_F.length("out_hosp_diagnosiscode")>=5).\
withColumn("ICD4", combine.out_hosp_diagnosiscode.substr(0,5)).\
filter(pyspark_F.col('ICD4').isin(list(icd_diagnosis_dict.keys()))).toPandas()
data_inhosp
# Out:
# 139229
# 44195071
# 136118
#                        register_no      per_no  age sex per_type   zone_name  \
# 0            219762348-1-330522012  f91c34b573   36   女     城镇职工  c7cdeaff4b
# 1            219762549-1-330522012  fe114e1d78   56   男     城镇职工  c7cdeaff4b
# 2            219786156-1-330522012  946df375b9   56   男     城镇职工  c7cdeaff4b
# 3            219851040-1-330522012  5a605afc4b   64   男     城镇居民  c7cdeaff4b
# 4            219851061-1-330522012  79af746d7c   27   女     城镇居民  c7cdeaff4b
# 5            219851488-1-330522012  255f7572c7   76   男     城镇居民  c7cdeaff4b
# 6            219908562-1-330522012  f40f42aefa   86   男     城镇居民  c7cdeaff4b
# 7            219908631-1-330522012  1df8f0475b   79   男     城镇职工  c7cdeaff4b
# 8            219935082-1-330522012  ccb2835bd1   72   男     城镇职工  c7cdeaff4b
# 9            219986664-1-330522012  61bf28584e   68   男     城镇职工  c7cdeaff4b
# 10           220019433-1-330522012  1cdf68a1fb   63   女     城镇职工  c7cdeaff4b
# 11           220048138-1-330522012  372c6b23e0   70   女     城镇职工  c7cdeaff4b
# 12           220048447-1-330522012  547eb47574   73   女     城镇职工  c7cdeaff4b
# 13           220048609-1-330522012  b0732d5039   44   男     城镇职工  c7cdeaff4b
# 14           220048644-1-330522012  13691c6b88   26   女     城镇职工  c7cdeaff4b
# 15           220078215-1-330522012  27ff511602   22   女     城镇居民  c7cdeaff4b
# 16           220078364-1-330522012  45f2e26d9d   61   男     城镇居民  c7cdeaff4b
# 17           220107066-1-330522012  466118801f   92   女     城镇居民  c7cdeaff4b
# 18           220136204-1-330522012  cc26041e10   69   女     城镇职工  c7cdeaff4b
# 19           220164305-1-330522012  c5015d8d9d   71   女     城镇职工  c7cdeaff4b
# 20           220164317-1-330522012  6810494d09   68   男     城镇居民  c7cdeaff4b
# 21           220164353-1-330522012  e4b593048b    8   男     城镇居民  c7cdeaff4b
# 22           220189029-1-330522012  2f2504de29   58   女     城镇居民  c7cdeaff4b
# 23           220189145-1-330522012  8016ba65be   69   男     城镇居民  c7cdeaff4b
# 24           220189158-1-330522012  bdbd882d98   67   女     城镇居民  c7cdeaff4b
# 25           220223381-1-330522012  71f01535e0    9   男     城镇居民  c7cdeaff4b
# 26           220284616-1-330522012  3df3704525    1   男     城镇居民  c7cdeaff4b
# 27           220284743-1-330522012  76f0e9d98c   51   男     城镇职工  c7cdeaff4b
# 28           220315462-1-330522012  203def98d7   53   男     城镇居民  c7cdeaff4b
# 29           220347188-1-330522012  b3a900037d   81   男     城镇职工  c7cdeaff4b
# ...                            ...         ...  ...  ..      ...         ...
# 84948     990934561521-1-330599012  2cf38e12ec   26   男     城镇职工  eacdb2c782
# 84949  990937449841-1-330599012-27  9063ef2803   82   女     城镇居民  acd9db4c1e
# 84950  990938516461-1-330599012-26  c5c0d53fbe   75   女     城镇居民  f3ab3890d4
# 84951     990939496601-1-330599012  09e1eac559   49   女     城镇职工  eacdb2c782
# 84952  990939696861-1-330599012-27  f2d9bdff81   61   男     城镇居民  acd9db4c1e
# 84953  990941290761-1-330599012-27  2ee617f674   70   男      390  acd9db4c1e
# 84954     990943251831-1-330599012  acc168d103   38   女     城镇职工  eacdb2c782
# 84955  990943769411-1-330599012-26  dc941c9ba9   50   女     城镇居民  f3ab3890d4
# 84956  990944268831-1-330599012-27  58d072e984   48   男     城镇居民  acd9db4c1e
# 84957  990945052531-1-330599012-26  9674370bc9   63   女      390  f3ab3890d4
# 84958     990945665241-1-330599012  9145569e99   78   男     城镇职工  eacdb2c782
# 84959  990946110301-1-330599012-27  76a1f2557a   70   女      390  acd9db4c1e
# 84960     990946617621-1-330599012  7b8e68ca7d   78   男     城镇职工  eacdb2c782
# 84961  990948900931-1-330599012-27  81607363d9   61   女     城镇居民  acd9db4c1e
# 84962  990949281191-1-330599012-27  3b55db8370   47   女     城镇居民  acd9db4c1e
# 84963  990949904431-1-330599012-26  2ececdf6e8   34   男     城镇居民  f3ab3890d4
# 84964     990951885431-1-330599012  d9c93d5f9c   47   女     城镇职工  eacdb2c782
# 84965  990951904381-1-330599012-27  be248635aa   64   男     城镇居民  acd9db4c1e
# 84966  990951921531-1-330599012-27  d688136ba9   61   女      390  acd9db4c1e
# 84967     990953390401-1-330599012  4f92914690   81   女      310  eacdb2c782
# 84968  990953481081-1-330599012-27  b906e0b7d4   71   男     城镇居民  acd9db4c1e
# 84969     990953484901-1-330599012  e1422ebaa6   80   男     城镇职工  eacdb2c782
# 84970     990957238251-1-330599012  0989f8af5c   54   男      310  eacdb2c782
# 84971  990957367421-1-330599012-26  bca128d344   29   女     城镇居民  f3ab3890d4
# 84972     990957509551-1-330599012  07cf236cea   40   男     城镇职工  eacdb2c782
# 84973     990960557811-1-330599012  cb4833aade   58   男     城镇职工  eacdb2c782
# 84974     990961546911-1-330599012  0b9a759eeb   73   男      310  eacdb2c782
# 84975     990962917431-1-330599012  96b10e968d   30   男     城镇职工  eacdb2c782
# 84976     990965640521-1-330599012  348d0c691e   58   女     城镇职工  eacdb2c782
# 84977     990975185891-1-330599012  4968823b4b   66   男     城镇职工  eacdb2c782
#
#       in_hosp_diagnosiscode in_hosp_diagnosisname out_hosp_diagnosisname  \
# 0                   K29.500                  慢性胃炎                   慢性胃炎
# 1                   M13.900                   关节炎                  半月板损伤
# 2                   R42.x00                 头晕和眩晕                  头晕和眩晕
# 3                   N40.x00                 前列腺增生                  前列腺增生
# 4                    syjtbx                生育津贴报销                 生育津贴报销
# 5                K80.200-01                  胆囊结石                   胆囊结石
# 6                   J44.100         慢性阻塞性肺病伴有急性加重          慢性阻塞性肺病伴有急性加重
# 7                   R42.x00                 头晕和眩晕                  头晕和眩晕
# 8                   J44.100         慢性阻塞性肺病伴有急性加重          慢性阻塞性肺病伴有急性加重
# 9                   I10.x00           特发性(原发性)高血压            特发性(原发性)高血压
# 10                  R10.401                   肠绞痛                    肠绞痛
# 11                  I10.x00           特发性(原发性)高血压            特发性(原发性)高血压
# 12                  D48.601                  乳腺肿瘤                 乳房恶性肿瘤
# 13                  L72.105                 皮脂腺囊肿                  皮脂腺囊肿
# 14                  O00.900                  异位妊娠                  女性盆腔炎
# 15                  J06.903                上呼吸道感染               急性上呼吸道感染
# 16                  K56.702                  结肠梗阻                   结肠梗阻
# 17                  H26.900                   白内障        单纯性（老年性）白内障（单眼）
# 18                  I51.900                   心脏病                    心脏病
# 19                  H81.901                 眩晕综合征                脑动脉供血不足
# 20                  K56.702                  结肠梗阻                   结肠梗阻
# 21                  J18.000                 支气管肺炎                  支气管肺炎
# 22                  Z43.603               取除输尿管支架                取除输尿管支架
# 23                  J44.100         慢性阻塞性肺病伴有急性加重                慢性阻塞性肺病
# 24                  J06.903                上呼吸道感染                 上呼吸道感染
# 25                  J03.900                急性扁桃体炎                 急性扁桃体炎
# 26                  J40.x00                  支气管炎                  支气管肺炎
# 27                  J98.414                  肺部感染          慢性阻塞性肺病伴有急性加重
# 28               S42.000-01                  锁骨骨折                   锁骨骨折
# 29                  J44.801            慢性支气管炎伴肺气肿     慢性阻塞性肺气肿性支气管炎伴急性加重
# ...                     ...                   ...                    ...
# 84948               J15.902           社区获得性肺炎，非重症            社区获得性肺炎，非重症
# 84949               M51.202                腰椎间盘突出                 腰椎间盘突出
# 84950               E14.900                   糖尿病                    糖尿病
# 84951               N73.902                 女性盆腔炎                  女性盆腔炎
# 84952               C34.900                 肺恶性肿瘤                  肺恶性肿瘤
# 84953               J42.x00                慢性支气管炎                慢性阻塞性肺病
# 84954               K29.500                  慢性胃炎                   慢性胃炎
# 84955               N92.401                 绝经期出血                 子宫内膜息肉
# 84956               R10.400                    腹痛                     腹痛
# 84957               E04.902               结节性甲状腺肿                  甲状腺结节
# 84958               J44.900               慢性阻塞性肺病           慢性阻塞性肺病伴急性加重
# 84959               I10.x00                  高血压病                   高血压病
# 84960               J98.414                  肺部感染                   肺部感染
# 84961               M13.900                   关节炎                    关节炎
# 84962               N72.x00                宫颈炎性疾病                 宫颈炎性疾病
# 84963               1171119                  脑血管病                    脑梗死
# 84964               N83.201                  卵巢囊肿                   卵巢囊肿
# 84965               N28.101                单纯性肾囊肿                取除输尿管支架
# 84966               Z47.001             取除骨折内固定装置              取除骨折内固定装置
# 84967               I25.103          冠状动脉粥样硬化性心脏病           冠状动脉粥样硬化性心脏病
# 84968               K35.900                 急性阑尾炎                  急性阑尾炎
# 84969               M17.900                  膝关节病              取除骨折内固定装置
# 84970               D17.900                   脂肪瘤                    脂肪瘤
# 84971               N73.902                 女性盆腔炎                  女性盆腔炎
# 84972               R00.200                    心悸                     胸痛
# 84973               C25.900                胰腺恶性肿瘤                  恶性肿瘤史
# 84974               N40.x00                 前列腺增生                  前列腺增生
# 84975               K80.101            胆囊结石伴慢性胆囊炎             胆囊结石伴慢性胆囊炎
# 84976               R22.903                  皮肤肿物                   皮肤肿物
# 84977               I10.x00                  高血压病                   高血压病
#
#       out_hosp_diagnosiscode  ... has_surgery sugery_fee herb_fee western_fee  \
# 0                    K29.500  ...           1     450.00     0.00      224.85
# 1                    M23.308  ...           1    2607.01     0.00     2426.48
# 2                    R42.x00  ...           0       0.00     0.00      264.78
# 3                    N40.x00  ...           0       0.00     0.00      348.48
# 4                     syjtbx  ...           0       0.00     0.00        0.00
# 5                 K80.200-01  ...           0       0.00     0.00     1849.39
# 6                    J44.100  ...           1       0.01   885.72     1988.88
# 7                    R42.x00  ...           0       0.00   680.12     1417.21
# 8                    J44.100  ...           0       0.00     0.00     2245.67
# 9                    I10.x00  ...           0       0.00     0.00      706.32
# 10                   R10.401  ...           0       0.00     0.00     3170.83
# 11                   I10.x00  ...           0       0.00   475.93     1837.88
# 12                   C50.900  ...           0       0.00   130.76     2166.43
# 13                   L72.105  ...           1     697.01     0.00        4.50
# 14                   N73.902  ...           0       0.00     0.00      524.70
# 15                   J06.900  ...           0       0.00    46.82      464.06
# 16                   K56.702  ...           1       0.01     0.00     1211.99
# 17                H25.900-20  ...           1    3228.00     0.00      203.06
# 18                   I51.900  ...           1      94.00     0.00     1208.95
# 19                   I67.803  ...           0       0.00     0.00      116.25
# 20                   K56.702  ...           1     608.00     0.00      719.45
# 21                   J18.000  ...           0       0.00     0.00      275.48
# 22                   Z43.603  ...           1       0.00     0.00        7.37
# 23                   J44.900  ...           0       0.00     0.00     1804.46
# 24                   J06.903  ...           0       0.00     0.00      339.10
# 25                   J03.900  ...           0       0.00     0.00     1145.99
# 26                   J18.000  ...           0       0.00   125.24     1505.18
# 27                   J44.100  ...           0       0.00     0.00     2500.87
# 28                   S42.000  ...           1    1348.00     0.00     1042.39
# 29                   J44.101  ...           0       0.00   682.64     5540.26
# ...                      ...  ...         ...        ...      ...         ...
# 84948                J15.902  ...           0       0.00     0.00     1248.42
# 84949                M51.202  ...           1    6145.00   184.80     1345.30
# 84950                E14.900  ...           0       0.00   142.92     1405.98
# 84951                N73.902  ...           0       0.00   613.74      132.30
# 84952                C34.900  ...           1     101.00     0.00     2839.11
# 84953                J44.900  ...           0       0.00   255.57     3133.48
# 84954                K29.500  ...           1     800.00     0.00       57.52
# 84955                N84.001  ...           1     589.00     0.00      600.52
# 84956                R10.400  ...           0       0.00     0.00       75.90
# 84957                E04.101  ...           1     176.00     0.00       33.66
# 84958                J44.100  ...           0       0.00     0.00     3058.80
# 84959                I10.x00  ...           0       0.00     0.00      710.06
# 84960                J98.414  ...           1      57.00     0.00     4345.56
# 84961                M13.900  ...           0       0.00     0.00      384.48
# 84962                N72.x00  ...           1     832.00     0.00       34.86
# 84963                I63.900  ...           0       0.00     0.00    16271.17
# 84964                N83.201  ...           1    2039.00     0.00     1670.00
# 84965                Z43.603  ...           1      20.00     0.00       24.38
# 84966                Z47.001  ...           1    1599.00     0.00      743.60
# 84967                I25.103  ...           0       0.00     0.00     2726.14
# 84968                K35.900  ...           1    1525.00   196.14      739.26
# 84969                Z47.001  ...           1    2138.00   650.61      742.87
# 84970                D17.900  ...           1     284.00   157.65        9.77
# 84971                N73.902  ...           1    1152.00   250.18     1092.13
# 84972                R07.400  ...           1      28.00     0.00      195.63
# 84973                Z85.901  ...           0       0.00     0.00     8763.41
# 84974                N40.x00  ...           0       0.00     0.00      566.01
# 84975                K80.101  ...           1    1207.80     0.00     1697.52
# 84976                R22.903  ...           1     441.00   209.20       37.36
# 84977                I10.x00  ...           0       0.00     0.00     1452.26
#
#       cn_med_fee bed_fee material_fee care_fee treat_fee   ICD4
# 0         172.00    70.0       122.40      0.0     59.30  K29.5
# 1           0.00   150.0      1537.99      0.0   1900.33  M23.3
# 2           0.00    13.0        47.15      0.0     87.00  R42.x
# 3           0.00    46.0         8.75      0.0    223.30  N40.x
# 4           0.00     0.0         0.00      0.0      0.00  syjtb
# 5          38.88   100.0        32.00      0.0     91.00  K80.2
# 6           0.00   320.0       125.96      0.0   2945.00  J44.1
# 7         101.86   180.0       140.40      0.0    739.00  R42.x
# 8           0.00   180.0       101.46      0.0   1485.00  J44.1
# 9         303.96   205.0        76.36      0.0    297.00  I10.x
# 10          0.00   252.0        55.05      0.0    555.50  R10.4
# 11          0.00   313.0        45.70      0.0    726.00  I10.x
# 12       1171.53   550.0        30.75      0.0    180.30  C50.9
# 13          0.00    10.0        56.34      0.0     89.00  L72.1
# 14          0.00   175.0       110.90      0.0    266.00  N73.9
# 15          0.00   200.0        69.20      0.0    594.01  J06.9
# 16         33.30   160.0        20.36      0.0    672.50  K56.7
# 17          0.00    36.0      2210.20      0.0    137.00  H25.9
# 18        713.02   304.0        89.60      0.0   3111.50  I51.9
# 19         95.08    82.0        51.13      0.0    405.50  I67.8
# 20          0.00   157.0        17.85      0.0    439.00  K56.7
# 21          0.00    40.0        19.10      0.0    114.00  J18.0
# 22          0.00    51.0        21.71      0.0    504.00  Z43.6
# 23          0.00   216.0        86.65      0.0    475.50  J44.9
# 24         49.96    40.0         8.00      0.0     32.00  J06.9
# 25        124.85   130.0        57.10      0.0    712.50  J03.9
# 26          0.00   360.0       139.90      0.0   1480.60  J18.0
# 27          0.00   301.0       107.53      0.0   1495.00  J44.1
# 28          0.00   132.0       371.35      0.0    520.00  S42.0
# 29         63.30   842.0       236.95      0.0   4186.00  J44.1
# ...          ...     ...          ...      ...       ...    ...
# 84948       2.16   215.0        52.58      0.0    358.00  J15.9
# 84949      63.56   172.0     27460.73      0.0    498.50  M51.2
# 84950       0.00   265.0        31.18      0.0    640.00  E14.9
# 84951     166.48   224.0         7.68      0.0   2016.20  N73.9
# 84952     369.00   215.0       231.25      0.0    571.50  C34.9
# 84953      66.32   430.0      1081.03      0.0    766.50  J44.9
# 84954       0.00   139.0      2947.16      0.0    321.00  K29.5
# 84955      16.55    53.0       886.60      0.0    978.00  N84.0
# 84956       0.00   159.0        32.41      0.0    252.00  R10.4
# 84957       0.00    41.0       516.31      0.0    213.00  E04.1
# 84958      97.40   395.0       133.67      0.0   2956.50  J44.1
# 84959    1037.60   371.0        14.19      0.0    635.00  I10.x
# 84960       0.00  1960.0       972.70      0.0   3466.20  J98.4
# 84961       0.00   212.0        16.23      0.0    187.00  M13.9
# 84962      88.86    43.0       241.55      0.0     80.00  N72.x
# 84963       0.00   459.0       176.71     50.0   4959.50  I63.9
# 84964      53.52   357.0       819.72    100.0   1971.40  N83.2
# 84965       0.00    28.0        21.98      0.0    501.50  Z43.6
# 84966     400.72   120.0      1780.15      0.0    326.30  Z47.0
# 84967     159.56   120.0        30.10      0.0    358.30  I25.1
# 84968     366.00   318.0       316.75      0.0    544.00  K35.9
# 84969       0.00   583.0        78.90      0.0    807.00  Z47.0
# 84970       0.00    28.0        56.00      0.0    178.00  D17.9
# 84971      71.31   245.0       182.16      0.0   1737.20  N73.9
# 84972      54.48   357.0       112.57      0.0    628.00  R07.4
# 84973       0.00   150.0       156.30      0.0    229.00  Z85.9
# 84974     141.24    35.0        10.50      0.0    302.30  N40.x
# 84975      31.21  1080.0      2644.26     50.0   1869.50  K80.1
# 84976       0.00    32.0       268.02      0.0    396.60  R22.9
# 84977       0.00    53.0         2.30      0.0     29.00  I10.x
#
# [84978 rows x 35 columns]

# %%
bs=64

data_fine_tuned = (TextList.from_df(data_inhosp,cols="details", processor=[FixSSP.load("./")])
             .split_by_rand_pct(0.1, seed=42)
             .label_for_lm()
             .databunch(bs=bs,bptt=50,num_workers=1))

# %%
lm_fns = ['./lm_wt', './lm_wt_vocab']

learn_lm = language_model_learner(data_fine_tuned, AWD_LSTM, pretrained_fnames=lm_fns, drop_mult=1.0, wd=0.1)

# %%
lr = 1e-3
lr *= bs/48

learn_lm.fit_one_cycle(1, lr*10, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.947487</td>
#       <td>0.852845</td>
#       <td>0.808070</td>
#       <td>11:40</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_lm.unfreeze()
learn_lm.fit_one_cycle(3, slice(lr/10,lr*10), moms=(0.8,0.7))

# %%
learn_lm.save(f'lm_fine_tuned')
learn_lm.save_encoder(f'lm_fine_tuned_enc')

# %%
def generate(prefix, predict_func, n_words=500, temp=1):
    out = [i for i in predict_func(
        prefix, n_words, temperature=temp).split(" ")]
    return "   ".join(out)

TEXT = "妇科检查"
predict_func = functools.partial(learn_lm.predict)
# AWD_learn.beam_search
generate(TEXT,predict_func=predict_func)
# Out:
# '妇科检查   ,   一   次   性   真   空   采   血   器   ,   妇   科   常规检查   ,   贴   敷   疗   法   ,   一   次   性   鼻   导   管   ,   自   费   费   用   ,   一   次   性   鼻   导   管   ,   即   毁   式   一   次   性   阴   道   扩   张   器   ,   静脉   置   管   冲   洗   ,   阴   道   灌   洗   上   药   ,   自   费   诊   疗   及   服务   项   目   ,   麻   醉   中   监测   (   <4   小时   )   ,   氯化钠   ,   静脉   穿   刺   置   管   术   ,   计   算   机   图   文   报   告   ,   无   机   磷   测定   ,   静脉   穿   刺   置   管   胺   ,   计   算   机   图   文   报   告   ,   鼻   导   管   吸   氧   ,   无   机   磷   测定   ,   心   肌   酶   谱   常规检查   ,   普   通   病   房   床   位   费   ,   乙   肝   e   抗体测定   ,   数字化   摄影   (   d   r   )   ,   左   卡   尼   汀   ,   静脉   穿   刺   置   管   术   ,   住院   诊查费   (   三   级   医院   )   ,   自   费   费   用   ,   静脉   穿   刺   置   管   术   ,   阴   道   分   泌   物   白   细胞   酯   酶   检查   ,   麻   醉   中   监测   (   <4   小时   )   ,   支   原   体   培   养   及   药   敏   ,   氯   化   钾   ,   计   算   机   图   文   报   告   ,   血   氧   饱   和   度   监测   ,   血   清   载   脂   蛋白   α   测定   ,   甲   肝   抗体测定   (   igm   )   ,   静脉   输液   (   住院   ▁/   ▁   含输液器   )   ,   丙   型   肝   炎   抗   体   igg   测定   ,   钙   测定   ,   无   机   磷   测定   ,   一   次   性   密   闭   输液   针   ,   抗   甲状腺球蛋白   抗体测定   (   t   ga   b   )   ,   一   般   灌   肠   ,   丙   型   肝   炎   抗   体   igg   测定   ,   普   通   病   房   床   位   费   ,   头   孢   他   啶   ,   血   脂   常规检查   ,   住院   诊查费   (   三   级   医院   )   ,   阴   道   分   泌   物   检查   ,   一   般   专   项   护   理   ,   一   般   细   菌   培   养   及   鉴   定   ,   刮   宫   术   ,   省   、   市离休干部可使用的治疗性西药   ,   丙   型   肝   炎   抗   体   igg   测定   ,   数字化   摄影   (   d   r   )   ,   血   清   β   -   羟   基   丁   酸   测定   ,   自   费   费   用   ,   一   次   性   鼻   导   管   ,   凝血   功   能   常规检查   ,   阴   道   分   泌   物   过   氧   化   氢   浓   度   检查   ,   钙   测定   (   急诊   )   ,   全   身   麻   醉   ,   低   分   子   肝   素   ,   脑   电   图   ,   超   敏   c   反应蛋白测定   ,   血   清   载   脂   蛋白   ai   测定   ,   刮   宫   术   ,   全   身   麻   醉   ,   血   常规   (   五   分类   )   ,   麻   醉   恢   复   室   监   护   ,   手   术   标   本   检查   与   诊   断   ,   一   次   性   留   置   针   ,   乳   酸   钠   林   格   ,'

# %% [markdown]
# ## 4.3 将语言模型的RNN编码器迁移到下游分类

# %%
train_df = data_inhosp[['details','ICD4']]
train_df
# Out:
#                                                  details   ICD4
# 0      血清人绒毛膜促性腺激素测定,淀粉酶测定,无机磷测定,葡萄糖,兰索拉唑,生化筛查常规检查,糖类...  K29.5
# 1      自费诊疗及服务项目,灸法(艾条灸),主肺动脉窗修补术,血清载脂蛋白B测定,钾测定,普通病房床...  M23.3
# 2      常规心电图检查,一次性真空采血器,血清载脂蛋白α测定,抗Sm抗体测定,血清总胆汁酸测定,淀粉...  R42.x
# 3      钙测定,16层及以上多排螺旋CT扫描加收,住院诊查费（二级医院),乙肝e抗体测定,碳[14C...  N40.x
# 4                                                         syjtb
# 5      粪便隐血试验(OB),血清胆碱脂酶测定,计算机图文报告,左卡尼汀,普通病房床位费,住院诊查费...  K80.2
# 6      多索茶碱,一般专项护理,计算机图文报告,自费诊疗及服务项目,抗核提取物抗体测定(抗ENA抗体...  J44.1
# 7      普通病房床位费,总前列腺特异性抗原测定(TPSA),MRI扫描增加各项功能加收,血清载脂蛋白...  R42.x
# 8      氨溴索,结核菌涂片检查,自费诊疗及服务项目,血清α-L-岩藻糖苷酶测定,贴敷疗法,计算机图文...  J44.1
# 9      真菌涂片检查,普通病房床位费,一次性真空采血器,氯化钾,等级护理（三级医院）,凝血功能常规检...  I10.x
# 10     血氧饱和度监测,兰索拉唑,血清载脂蛋白B测定,一次性真空采血器,葡萄糖测定,血清脂肪酶测定,...  R10.4
# 11     氯化钠,一般专项护理,住院诊查费（三级医院),血清促甲状腺激素测定,鼻导管吸氧,血清白蛋白测...  I10.x
# 12     血清丙氨酸氨基转移酶测定,血清α-L-岩藻糖苷酶测定,红细胞沉降率测定(ESR),舒血宁注射...  C50.9
# 13     卡式配血加收,ABO血型鉴定,常规心电图检查,血浆凝血酶原时间测定(PT),麻醉中监测（＜4...  L72.1
# 14     住院诊查费（二级医院),自费一次性材料,计算机图文报告,普通病房床位费,等级护理（二级医院）...  N73.9
# 15     静脉注射,一次性注射器,陈皮（配方颗粒）,黄芩（配方颗粒）,葡萄糖,超敏C反应蛋白测定,自费...  J06.9
# 16     强力枇杷露（胶囊）,氯化钠,静脉穿刺置管术,兰索拉唑,穴位贴敷治疗,铁蛋白测定,头孢呋辛,自...  K56.7
# 17     凝血酶时间测定(TT),普拉洛芬,数字化摄影(DR),血清丙氨酸氨基转移酶测定,血浆纤维蛋白...  H25.9
# 18     心电监护,动脉采血,倍他司汀,一次性注射器,胆酸测定,住院诊查费（三级医院),等级护理（三级...  I51.9
# 19     甲状腺功能常规检查,血氧饱和度监测,血清果糖胺测定,丹参注射液,氯苯那敏,电解质测定,血清载...  I67.8
# 20     血清甘油三酯测定,血清高密度脂蛋白胆固醇测定,头孢呋辛,静脉置管冲洗,糖类抗原CA-125测...  K56.7
# 21     流行性乙型脑炎病毒(IgM),一次性真空采血器,葡萄糖,氧气雾化吸入,特布他林,一次性面罩,...  J18.0
# 22     尿素测定（急诊）,氯化钠,粪便隐血试验(OB),静脉采血,血浆D-二聚体测定(D-Dimer...  Z43.6
# 23     一次性真空采血器,静脉输液（住院/含输液器）,血清尿酸测定,专项变应原(单价变应原)筛查,自...  J44.9
# 24     血清载脂蛋白E测定,血清载脂蛋白α测定,癌胚抗原测定(CEA),糖类抗原CA19-9测定,静...  J06.9
# 25     副流感病毒抗体测定（IgG）,贴敷疗法,中药涂擦治疗（10%体表面积）,葡萄糖氯化钠,穴位贴...  J03.9
# 26     中药涂擦治疗（10%体表面积）,静脉置管冲洗,特布他林,头孢呋辛,自费诊疗及服务项目,血清总...  J18.0
# 27     纤维结合蛋白测定(Fn),莫西沙星,一次性密闭输液接头,心肌酶谱常规检查,等级护理（三级医院...  J44.1
# 28     一次性注射器,静脉穿刺置管术,等级护理（三级医院）,静脉置管冲洗,一次性留置针,血清总蛋白测...  S42.0
# 29     自费诊疗及服务项目,24小时动态心电图,血氧饱和度监测,氯化钠,心电监护,鼻导管吸氧,头孢哌...  J44.1
# ...                                                  ...    ...
# 84948  氨溴索,静脉注射,益肝灵胶囊（片）,等级护理（三级医院）,氯化钠,真菌培养及鉴定,抗增殖细胞...  J15.9
# 84949  钾测定,贴敷疗法,茯苓（配方颗粒）,钠测定,维生素C,活化部分凝血活酶时间测定(APTT),...  M51.2
# 84950  乙肝病毒外膜蛋白前S1抗原测定,快速血浆反应素试验(RPR),血浆D-二聚体测定(D-Dim...  E14.9
# 84951  乙肝病毒外膜蛋白前S2抗原测定,血清胆碱脂酶测定,妇科微波治疗,数字化摄影(DR),香附,柴...  N73.9
# 84952  血清α羟基丁酸脱氢酶测定,纤维结合蛋白测定(Fn),氯化钠,一次性注射器,常规心电图检查,一...  C34.9
# 84953  葡萄糖测定,住院诊查费（二级医院),多索茶碱,布地奈德,贴敷疗法,异丙托溴铵,氯化钠,二羟丙...  J44.9
# 84954  血常规（五分类）,乳腺肿物切除术（单侧）,Rh血型鉴定,钠测定,血清总胆汁酸测定,浅表器官彩...  K29.5
# 84955  即毁式一次性阴道扩张器,肌肉注射,间苯三酚,血清丙氨酸氨基转移酶测定,一次性真空采血器,一次...  N84.0
# 84956  血同型半胱氨酸测定,螺旋CT增强扫描（≥三个部位）,ABO血型鉴定,全血粘度测定（低切）,多...  R10.4
# 84957  钙测定,计算机图文报告,一次性真空采血器,镁测定,等级护理（三级医院）,敷贴,硝苯地平,凝血...  E04.1
# 84958  布地奈德,氯化钠,四肢血管彩色多普勒超声,氨溴索,葡萄糖测定,静脉注射,左心功能测定,氧气雾...  J44.1
# 84959  甲钴胺,计算机图文报告,钾测定（急诊）,葡萄糖测定,丹红注射液,血清尿酸测定,血氧饱和度监测...  I10.x
# 84960  美洛西林舒巴坦,布地奈德,复方甲氧那明,静脉输液（住院/不含输液器）,异丙托溴铵,左氧氟沙星...  J98.4
# 84961  左心功能测定,氯化钾,类风湿因子(RF)测定,常规心电图检查,四肢血管彩色多普勒超声,超敏C...  M13.9
# 84962  电凝切割器,活化部分凝血活酶时间测定(APTT),麻醉中监测（＜4小时）,血浆纤维蛋白原测定...  N72.x
# 84963  鼻导管吸氧,等级护理（三级医院）,氯化钠,胞磷胆碱（胞二磷胆碱）,住院诊查费（三级医院),静...  I63.9
# 84964  血氧饱和度监测,氯化钠,自费诊疗及服务项目,省、市离休门诊、住院可使用的一次性材料,特级护理...  N83.2
# 84965  经膀胱镜输尿管支架取出术,梅毒螺旋体特异抗体测定,静脉采血,氯化钠,螺旋CT平扫（一个部位）...  Z43.6
# 84966  血清直接胆红素测定,注射用脂溶性维生素（II）／注射用水溶性维生素组合包装,省、市离休住院可...  Z47.0
# 84967  氯化钠,鼻导管吸氧,等级护理（二级医院）,血清载脂蛋白AⅠ测定,血清γ-谷氨酰基转移酶测定,...  I25.1
# 84968  氯化钠,鼻导管吸氧,一次性注射器,心电监护,钙测定,血氧饱和度监测,维生素C,凝血功能常规检...  K35.9
# 84969  普通病房床位费,住院诊查费（三级医院),一次性真空采血器,粪寄生虫镜检,自费一次性材料,麻醉...  Z47.0
# 84970  赤芍（配方颗粒）,黄连（配方颗粒）,氯化钠,敷贴,牡丹皮（配方颗粒）,卡式配血加收,乙肝表面...  D17.9
# 84971  血清亮氨酰氨基肽酶测定,甲肝抗体测定(IgG),麻醉恢复室监护,省、市离休干部可使用的治疗性...  N73.9
# 84972  血清天门冬氨酸氨基转移酶测定,尿微量白蛋白测定,免疫球蛋白IgA定量测定,静脉输液（住院/含...  R07.4
# 84973  利可君(利血生),血氧饱和度监测,钾测定,血清天门冬氨酸氨基转移酶测定,等级护理（三级医院）...  Z85.9
# 84974  肺弥散功能检查,省、市离休门诊、住院可使用的诊疗项目,乙肝表面抗体测定(Anti-HBs),...  N40.x
# 84975  敷贴,麻醉恢复室监护,普通病房床位费,凝血功能常规检查,肾功能常规检查,糖类抗原CA-125...  K80.1
# 84976  穿刺组织活检检查与诊断,尿素氮测定（急诊）,山药（配方颗粒）,静脉穿刺置管术,视黄醇结合蛋白...  R22.9
# 84977  瑞舒伐他汀,ABO血型鉴定,肝功能常规检查,铁测定,血清载脂蛋白AⅠ测定,血清胆碱脂酶测定,...  I10.x
#
# [84978 rows x 2 columns]

# %%
# import catboost
# catboost.__version__
# Out:
# '0.23.2'

# %%
bs=64

# %%
data_clas = (TextList.from_df(train_df, cols='details', processor=FixSSP.load("./"))
    .split_by_rand_pct(0.1, seed=42)
    .label_from_df(cols='ICD4')
    .databunch(bs=bs, num_workers=1))

# %%
learn_c = text_classifier_learner(data_clas, AWD_LSTM, drop_mult=0.5, pretrained=False, wd=0.1).to_fp16()
learn_c.load_encoder(f'lm_fine_tuned_enc')
learn_c.freeze()

lr=2e-2
lr *= bs/48

learn_c.fit_one_cycle(2, lr, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.173878</td>
#       <td>2.169117</td>
#       <td>0.428504</td>
#       <td>03:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.793146</td>
#       <td>1.685692</td>
#       <td>0.544192</td>
#       <td>04:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_c.fit_one_cycle(2, lr, moms=(0.8,0.7))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 03:42<03:42]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.177176</td>
#       <td>2.096181</td>
#       <td>0.463693</td>
#       <td>03:42</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='156' class='' max='1195', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       13.05% [156/1195 00:33<03:44 2.0997]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-75b117ad0bce> in <module>
# ----> 1 learn_c.fit_one_cycle(2, lr, moms=(0.8,0.7))
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      21     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      22                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 23     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      24
#      25 def fit_fc(learn:Learner, tot_epochs:int=1, lr:float=defaults.lr,  moms:Tuple[float,float]=(0.95,0.85), start_pct:float=0.72,
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      24     if not is_listy(xb): xb = [xb]
#      25     if not is_listy(yb): yb = [yb]
# ---> 26     out = model(*xb)
#      27     out = cb_handler.on_loss_begin(out)
#      28
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/fastai/text/learner.py in forward(self, input)
#     263         raw_outputs,outputs,masks = [],[],[]
#     264         for i in range(0, sl, self.bptt):
# --> 265             r, o = self.module(input[:,i: min(i+self.bptt, sl)])
#     266             if i>(sl-self.max_len):
#     267                 masks.append(input[:,i: min(i+self.bptt, sl)] == self.pad_idx)
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/fastai/text/models/awd_lstm.py in forward(self, input, from_embeddings)
#     119         new_hidden,raw_outputs,outputs = [],[],[]
#     120         for l, (rnn,hid_dp) in enumerate(zip(self.rnns, self.hidden_dps)):
# --> 121             raw_output, new_h = rnn(raw_output, self.hidden[l])
#     122             new_hidden.append(new_h)
#     123             raw_outputs.append(raw_output)
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/fastai/text/models/awd_lstm.py in forward(self, *args)
#      52             #To avoid the warning that comes because the weights aren't flattened.
#      53             warnings.simplefilter("ignore")
# ---> 54             return self.module.forward(*args)
#      55
#      56     def reset(self):
#
# /media/data1/ubuntu/repository/zhaohang/RiskAnalytics/src/main/python/venv/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     575         if batch_sizes is None:
#     576             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 577                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     578         else:
#     579             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# KeyboardInterrupt:

# %%
# Out:
# SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(1816, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(1816, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=118, bias=True)
#     )
#   )
# )

# %%
learn_c.export()

# %% [markdown]
# ## 4.4 数据可视化

# %%
def get_emcoding(details,
                model=learn_c):
    encoder = model.model[0]
    out = []
    for i in tqdm(range(len(icdSeq)), position=0, leave=True):
        encoder.reset()
        xb, yb = model.data.one_item(icdSeq[i])
        with torch.no_grad():
            encoded = encoder.eval()(xb)
#             pdb.set_trace()
            out.append(encoded[0][-1][0][-1].detach())
#     pdb.set_trace()
    res = torch.stack(out, dim=0)
    return res

# %% [markdown]
# # 5. 结合迁移学习和 Few-shot Metrics learning 小样本学习实现极小病种诊断的高精度分类

# %% [raw]
#  Prototypical Network: https://arxiv.org/pdf/1703.05175.pdf

# %% [markdown]
# # 6. 使用模型
